# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('../data/cocktail_dataset.json')

# %%
df.head()
# Out:
# Empty DataFrame
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Columns: 13272 entries, [{"id":11000 to measure:"1/8 tsp grated "}]}]
# dtypes: object(13272)
# memory usage: 132.0+ bytes

# %%
df.describe()
# Out:
#        [{"id":11000 name:"Mojito" category:"Cocktail" glass:"Highball glass"  \
# count             0             0                   0                      0
# unique            0             0                   0                      0
# top             NaN           NaN                 NaN                    NaN
# freq            NaN           NaN                 NaN                    NaN
#
#        tags:["IBA" ContemporaryClassic Alcoholic  USA Asia Vegan  ...  \
# count            0                   0         0    0    0     0  ...
# unique           0                   0         0    0    0     0  ...
# top            NaN                 NaN       NaN  NaN  NaN   NaN  ...
# freq           NaN                 NaN       NaN  NaN  NaN   NaN  ...
#
#        {"id":344.4 name:"Nutmeg".4 description:null.223 alcohol:0.282  \
# count            0               0                    0             0
# unique           0               0                    0             0
# ...
